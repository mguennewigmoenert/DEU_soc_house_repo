# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_stata("C:/Users/laura/Desktop/Housing/SocialHousing/data/temp/plrs_neighbors_cleaned.dta")
df1.head()
# Out:
#      PLR_ID                                          neighbors dir_neighbor1  \
# 0  11501341   11501238, 11501340, 09200512, 09200510, 11501339      11501238
# 1  07601340             07601339, 07601237, 07601236, 07601341      07601339
# 2  02500831   02500832, 02500728, 02500830, 02500833, 02500729      02500832
# 3  12601134  12601235, 12500929, 12601133, 12500926, 126010...      12601235
# 4  07601547             07601548, 07601545, 07601546, 07601544      07601548
#
#   dir_neighbor2 dir_neighbor3 dir_neighbor4 dir_neighbor5 dir_neighbor6  \
# 0      11501340      09200512      09200510      11501339
# 1      07601237      07601236      07601341
# 2      02500728      02500830      02500833      02500729
# 3      12500929      12601133      12500926      12601031      12601236
# 4      07601545      07601546      07601544
#
#   dir_neighbor7 dir_neighbor8 dir_neighbor9 dir_neighbor10 dir_neighbor11  \
# 0
# 1
# 2
# 3      12500927
# 4
#
# ...

# %%
df1['adj_neighbor'] = ''

# %%
for value in df1.dir_neighbor1:
    
    if df1['PLR_ID']== value:
# Out:
# 0      11501238
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 537         NaN
# 538         NaN
# 539         NaN
# 540         NaN
# 541         NaN
# Name: dir_neighbor1, Length: 542, dtype: object
# 0           NaN
# 1      07601339
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 537         NaN
# 538         NaN
# 539         NaN
# 540         NaN
# 541         NaN
# Name: dir_neighbor1, Length: 542, dtype: object
# 0           NaN
# 1           NaN
# 2      02500832
# 3           NaN
# 4           NaN
#          ...
# 537         NaN
# 538         NaN
# 539         NaN
# 540         NaN
# 541         NaN
# Name: dir_neighbor1, Length: 542, dtype: object
# 0           NaN
# 1           NaN
# 2           NaN
# 3      12601235
# 4           NaN
#          ...
# 537         NaN
# 538         NaN
# 539         NaN
# 540         NaN
# 541         NaN
# Name: dir_neighbor1, Length: 542, dtype: object
# 0           NaN
# ...
